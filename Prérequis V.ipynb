# %% [markdown]
# <font color="green"> <h3 align="left">Étude de Cas : Streaming de Données Vélib avec Kafka en Python</h3></font>
# <p><b>Contexte :</b> Vous êtes chargé de développer un système de streaming de données pour collecter et afficher en temps réel les informations des stations Vélib de Paris. L'utilisation de Kafka est essentielle pour gérer efficacement le flux de données.</p>
# <p><b>Données de données:</b> https://velib-metropole-opendata.smoove.pro/opendata/Velib_Metropole/station_status.json</p>
#
# <p><b>Objectifs :</b></p>
# <ul>
# <li><b>Collecte des Données de Vélib :</b>
#     <ul>
#     <li>Développez un script Python nommé <code>producer.py</code> qui collecte les données en temps réel de l'API Vélib.</li>
#     <li>Envoyez ces données à un topic Kafka nommé <code>velib</code>.</li>
#     <li>Le script doit être exécutable via un terminal avec la commande <code>python producer.py</code>.</li>
#     </ul>
# </li>
# <li><b>Traitement et Affichage des Données :</b>
#     <ul>
#     <li>Réalisez un second script Python nommé <code>consumer.py</code> qui lit les données du topic Kafka <code>velib</code>.</li>
#     <li>Le script doit afficher les données récupérées en temps réel.</li>
#     <li>Lancez ce script via un terminal avec la commande <code>python consumer.py</code>.</li>
#     </ul>
# </li>
# </ul>

# %%
import requests
import json
response = requests.get('https://velib-metropole-opendata.smovengo.cloud/opendata/Velib_Metropole/station_status.json')
data_velib = response.json()

information_data = []
for i in data_velib['data']['stations']:
    information_data.append(i)

information_data
# Out:
# [{'stationCode': '16107',
#   'station_id': 213688169,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 5}, {'ebike': 0}],
#   'num_docks_available': 30,
#   'numDocksAvailable': 30,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051820},
#  {'stationCode': '31104',
#   'station_id': 653222953,
#   'num_bikes_available': 22,
#   'numBikesAvailable': 22,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 18}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052029},
#  {'stationCode': '44015',
#   'station_id': 17278902806,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051789},
#  {'stationCode': '9020',
#   'station_id': 36255,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 4}],
#   'num_docks_available': 15,
#   'numDocksAvailable': 15,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051989},
#  {'stationCode': '12109',
#   'station_id': 37815204,
#   'num_bikes_available': 9,
#   'numBikesAvailable': 9,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 2}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052204},
#  {'stationCode': '14111',
#   'station_id': 251039991,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 2}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052179},
#  {'stationCode': '14014',
#   'station_id': 85002689,
#   'num_bikes_available': 12,
#   'numBikesAvailable': 12,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 8}],
#   'num_docks_available': 47,
#   'numDocksAvailable': 47,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052140},
#  {'stationCode': '32017',
#   'station_id': 2515829865,
#   'num_bikes_available': 15,
#   'numBikesAvailable': 15,
#   'num_bikes_available_types': [{'mechanical': 5}, {'ebike': 10}],
#   'num_docks_available': 6,
#   'numDocksAvailable': 6,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052167},
#  {'stationCode': '11104',
#   'station_id': 516709288,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 2}],
#   'num_docks_available': 15,
#   'numDocksAvailable': 15,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052173},
#  {'stationCode': '8026',
#   'station_id': 120827885,
#   'num_bikes_available': 11,
#   'numBikesAvailable': 11,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 7}],
#   'num_docks_available': 1,
#   'numDocksAvailable': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051972},
#  {'stationCode': '13007',
#   'station_id': 66491398,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 2}],
#   'num_docks_available': 46,
#   'numDocksAvailable': 46,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052191},
#  {'stationCode': '6003',
#   'station_id': 37874517,
#   'num_bikes_available': 10,
#   'numBikesAvailable': 10,
#   'num_bikes_available_types': [{'mechanical': 6}, {'ebike': 4}],
#   'num_docks_available': 10,
#   'numDocksAvailable': 10,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052192},
#  {'stationCode': '7002',
#   'station_id': 210565680,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 1}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052173},
#  {'stationCode': '5110',
#   'station_id': 210403080,
#   'num_bikes_available': 23,
#   'numBikesAvailable': 23,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 16}],
#   'num_docks_available': 0,
#   'numDocksAvailable': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052085},
#  {'stationCode': '6108',
#   'station_id': 210561800,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 0}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052021},
#  {'stationCode': '33006',
#   'station_id': 209063434,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 6}, {'ebike': 2}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052081},
#  {'stationCode': '42016',
#   'station_id': 94555589,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 3}],
#   'num_docks_available': 24,
#   'numDocksAvailable': 24,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052170},
#  {'stationCode': '41301',
#   'station_id': 244498842,
#   'num_bikes_available': 20,
#   'numBikesAvailable': 20,
#   'num_bikes_available_types': [{'mechanical': 12}, {'ebike': 8}],
#   'num_docks_available': 29,
#   'numDocksAvailable': 29,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052173},
#  {'stationCode': '6021',
#   'station_id': 210405211,
#   'num_bikes_available': 12,
#   'numBikesAvailable': 12,
#   'num_bikes_available_types': [{'mechanical': 5}, {'ebike': 7}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052073},
#  {'stationCode': '21010',
#   'station_id': 43195240,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 4}],
#   'num_docks_available': 18,
#   'numDocksAvailable': 18,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052157},
#  {'stationCode': '25006',
#   'station_id': 501862076,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 21,
#   'numDocksAvailable': 21,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052186},
#  {'stationCode': '30002',
#   'station_id': 17486274358,
#   'num_bikes_available': 16,
#   'numBikesAvailable': 16,
#   'num_bikes_available_types': [{'mechanical': 13}, {'ebike': 3}],
#   'num_docks_available': 24,
#   'numDocksAvailable': 24,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052098},
#  {'stationCode': '17038',
#   'station_id': 207633746,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 4}],
#   'num_docks_available': 51,
#   'numDocksAvailable': 51,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052202},
#  {'stationCode': '15202',
#   'station_id': 16560752067,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 29,
#   'numDocksAvailable': 29,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052029},
#  {'stationCode': '7003',
#   'station_id': 210566542,
#   'num_bikes_available': 36,
#   'numBikesAvailable': 36,
#   'num_bikes_available_types': [{'mechanical': 23}, {'ebike': 13}],
#   'num_docks_available': 22,
#   'numDocksAvailable': 22,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052179},
#  {'stationCode': '17041',
#   'station_id': 85043758,
#   'num_bikes_available': 21,
#   'numBikesAvailable': 21,
#   'num_bikes_available_types': [{'mechanical': 14}, {'ebike': 7}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052205},
#  {'stationCode': '17026',
#   'station_id': 54000559,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 6}, {'ebike': 1}],
#   'num_docks_available': 29,
#   'numDocksAvailable': 29,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052117},
#  {'stationCode': '5016',
#   'station_id': 210397939,
#   'num_bikes_available': 16,
#   'numBikesAvailable': 16,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 15}],
#   'num_docks_available': 1,
#   'numDocksAvailable': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052191},
#  {'stationCode': '11025',
#   'station_id': 82405965,
#   'num_bikes_available': 22,
#   'numBikesAvailable': 22,
#   'num_bikes_available_types': [{'mechanical': 16}, {'ebike': 6}],
#   'num_docks_available': 19,
#   'numDocksAvailable': 19,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051991},
#  {'stationCode': '15047',
#   'station_id': 213682736,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 4}],
#   'num_docks_available': 46,
#   'numDocksAvailable': 46,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052089},
#  {'stationCode': '8050',
#   'station_id': 128986726,
#   'num_bikes_available': 18,
#   'numBikesAvailable': 18,
#   'num_bikes_available_types': [{'mechanical': 11}, {'ebike': 7}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051989},
#  {'stationCode': '13101',
#   'station_id': 54000581,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 0}],
#   'num_docks_available': 29,
#   'numDocksAvailable': 29,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051910},
#  {'stationCode': '14108',
#   'station_id': 13105968,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 0}],
#   'num_docks_available': 19,
#   'numDocksAvailable': 19,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052039},
#  {'stationCode': '31024',
#   'station_id': 653208733,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 37,
#   'numDocksAvailable': 37,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051845},
#  {'stationCode': '15026',
#   'station_id': 27415224,
#   'num_bikes_available': 22,
#   'numBikesAvailable': 22,
#   'num_bikes_available_types': [{'mechanical': 18}, {'ebike': 4}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052147},
#  {'stationCode': '47007',
#   'station_id': 907054879,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 0,
#   'is_renting': 0,
#   'last_reported': 1694836503},
#  {'stationCode': '17044',
#   'station_id': 129094535,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 3}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052171},
#  {'stationCode': '19033',
#   'station_id': 54000612,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 0}],
#   'num_docks_available': 38,
#   'numDocksAvailable': 38,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051647},
#  {'stationCode': '17025',
#   'station_id': 80101533,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 30,
#   'numDocksAvailable': 30,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052147},
#  {'stationCode': '21326',
#   'station_id': 17486876370,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 5}],
#   'num_docks_available': 14,
#   'numDocksAvailable': 14,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051774},
#  {'stationCode': '20143',
#   'station_id': 599135701,
#   'num_bikes_available': 9,
#   'numBikesAvailable': 9,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 7}],
#   'num_docks_available': 31,
#   'numDocksAvailable': 31,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052101},
#  {'stationCode': '43002',
#   'station_id': 102747146,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 1}],
#   'num_docks_available': 21,
#   'numDocksAvailable': 21,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052093},
#  {'stationCode': '16138',
#   'station_id': 2515403527,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 7}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052126},
#  {'stationCode': '21216',
#   'station_id': 653132534,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 24,
#   'numDocksAvailable': 24,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052204},
#  {'stationCode': '15068',
#   'station_id': 506455295,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 3}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052186},
#  {'stationCode': '22207',
#   'station_id': 1057149522,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 2}],
#   'num_docks_available': 16,
#   'numDocksAvailable': 16,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052035},
#  {'stationCode': '7004',
#   'station_id': 210567545,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 1}],
#   'num_docks_available': 9,
#   'numDocksAvailable': 9,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052198},
#  {'stationCode': '92002',
#   'station_id': 653197324,
#   'num_bikes_available': 10,
#   'numBikesAvailable': 10,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 7}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052186},
#  {'stationCode': '13030',
#   'station_id': 2515085147,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 5}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052024},
#  {'stationCode': '19027',
#   'station_id': 42950839,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 18,
#   'numDocksAvailable': 18,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051985},
#  {'stationCode': '31028',
#   'station_id': 14813797734,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 2}],
#   'num_docks_available': 24,
#   'numDocksAvailable': 24,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051956},
#  {'stationCode': '17048',
#   'station_id': 88230992,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 1}],
#   'num_docks_available': 27,
#   'numDocksAvailable': 27,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051775},
#  {'stationCode': '44017',
#   'station_id': 499303158,
#   'num_bikes_available': 26,
#   'numBikesAvailable': 26,
#   'num_bikes_available_types': [{'mechanical': 22}, {'ebike': 4}],
#   'num_docks_available': 4,
#   'numDocksAvailable': 4,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052193},
#  {'stationCode': '10013',
#   'station_id': 123095125,
#   'num_bikes_available': 9,
#   'numBikesAvailable': 9,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 6}],
#   'num_docks_available': 50,
#   'numDocksAvailable': 50,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052196},
#  {'stationCode': '16118',
#   'station_id': 27415302,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 1}],
#   'num_docks_available': 21,
#   'numDocksAvailable': 21,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051950},
#  {'stationCode': '2017',
#   'station_id': 27414512,
#   'num_bikes_available': 14,
#   'numBikesAvailable': 14,
#   'num_bikes_available_types': [{'mechanical': 14}, {'ebike': 0}],
#   'num_docks_available': 25,
#   'numDocksAvailable': 25,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052032},
#  {'stationCode': '9008',
#   'station_id': 210580039,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 4}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052115},
#  {'stationCode': '8103',
#   'station_id': 49474389,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 0}],
#   'num_docks_available': 21,
#   'numDocksAvailable': 21,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052157},
#  {'stationCode': '8048',
#   'station_id': 128940135,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 3}],
#   'num_docks_available': 14,
#   'numDocksAvailable': 14,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052125},
#  {'stationCode': '14013',
#   'station_id': 35149611,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 2}],
#   'num_docks_available': 10,
#   'numDocksAvailable': 10,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051693},
#  {'stationCode': '13118',
#   'station_id': 1057296253,
#   'num_bikes_available': 53,
#   'numBikesAvailable': 53,
#   'num_bikes_available_types': [{'mechanical': 51}, {'ebike': 2}],
#   'num_docks_available': 10,
#   'numDocksAvailable': 10,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052057},
#  {'stationCode': '18111',
#   'station_id': 129107656,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 2}],
#   'num_docks_available': 22,
#   'numDocksAvailable': 22,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052165},
#  {'stationCode': '9002',
#   'station_id': 210574471,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052088},
#  {'stationCode': '48003',
#   'station_id': 1057228658,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 2}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051733},
#  {'stationCode': '16110',
#   'station_id': 230873471,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 18,
#   'numDocksAvailable': 18,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052036},
#  {'stationCode': '14002',
#   'station_id': 205047993,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 42,
#   'numDocksAvailable': 42,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052100},
#  {'stationCode': '9014',
#   'station_id': 39799329,
#   'num_bikes_available': 20,
#   'numBikesAvailable': 20,
#   'num_bikes_available_types': [{'mechanical': 13}, {'ebike': 7}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052179},
#  {'stationCode': '43009',
#   'station_id': 129164969,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 4}],
#   'num_docks_available': 42,
#   'numDocksAvailable': 42,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052168},
#  {'stationCode': '8053',
#   'station_id': 128989986,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 5}],
#   'num_docks_available': 16,
#   'numDocksAvailable': 16,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052075},
#  {'stationCode': '9001',
#   'station_id': 129004826,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 2}],
#   'num_docks_available': 12,
#   'numDocksAvailable': 12,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051961},
#  {'stationCode': '17032',
#   'station_id': 518825709,
#   'num_bikes_available': 13,
#   'numBikesAvailable': 13,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 9}],
#   'num_docks_available': 7,
#   'numDocksAvailable': 7,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052173},
#  {'stationCode': '8016',
#   'station_id': 128930462,
#   'num_bikes_available': 27,
#   'numBikesAvailable': 27,
#   'num_bikes_available_types': [{'mechanical': 23}, {'ebike': 4}],
#   'num_docks_available': 1,
#   'numDocksAvailable': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052194},
#  {'stationCode': '10162',
#   'station_id': 911767210,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 1}],
#   'num_docks_available': 22,
#   'numDocksAvailable': 22,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051626},
#  {'stationCode': '10115',
#   'station_id': 54000565,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 1}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051699},
#  {'stationCode': '10029',
#   'station_id': 210586093,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 2}],
#   'num_docks_available': 21,
#   'numDocksAvailable': 21,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052190},
#  {'stationCode': '5005',
#   'station_id': 7254,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 7}],
#   'num_docks_available': 15,
#   'numDocksAvailable': 15,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051799},
#  {'stationCode': '10161',
#   'station_id': 369644630,
#   'num_bikes_available': 14,
#   'numBikesAvailable': 14,
#   'num_bikes_available_types': [{'mechanical': 6}, {'ebike': 8}],
#   'num_docks_available': 18,
#   'numDocksAvailable': 18,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051962},
#  {'stationCode': '41303',
#   'station_id': 214114469,
#   'num_bikes_available': 17,
#   'numBikesAvailable': 17,
#   'num_bikes_available_types': [{'mechanical': 15}, {'ebike': 2}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052084},
#  {'stationCode': '12031',
#   'station_id': 55927887,
#   'num_bikes_available': 35,
#   'numBikesAvailable': 35,
#   'num_bikes_available_types': [{'mechanical': 29}, {'ebike': 6}],
#   'num_docks_available': 1,
#   'numDocksAvailable': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052109},
#  {'stationCode': '7011',
#   'station_id': 210570888,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 1}],
#   'num_docks_available': 14,
#   'numDocksAvailable': 14,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052107},
#  {'stationCode': '7018',
#   'station_id': 128887067,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 5}, {'ebike': 1}],
#   'num_docks_available': 9,
#   'numDocksAvailable': 9,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052204},
#  {'stationCode': '5022',
#   'station_id': 72765603,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 3}],
#   'num_docks_available': 14,
#   'numDocksAvailable': 14,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052113},
#  {'stationCode': '9106',
#   'station_id': 210582921,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 2}],
#   'num_docks_available': 7,
#   'numDocksAvailable': 7,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052181},
#  {'stationCode': '21328',
#   'station_id': 16659953198,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 28,
#   'numDocksAvailable': 28,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052034},
#  {'stationCode': '21323',
#   'station_id': 17486828694,
#   'num_bikes_available': 23,
#   'numBikesAvailable': 23,
#   'num_bikes_available_types': [{'mechanical': 18}, {'ebike': 5}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052193},
#  {'stationCode': '8201',
#   'station_id': 16659964929,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 3}],
#   'num_docks_available': 26,
#   'numDocksAvailable': 26,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051880},
#  {'stationCode': '18134',
#   'station_id': 507934805,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 25,
#   'numDocksAvailable': 25,
#   'is_installed': 1,
#   'is_returning': 0,
#   'is_renting': 0,
#   'last_reported': 1702052161},
#  {'stationCode': '17040',
#   'station_id': 43255030,
#   'num_bikes_available': 10,
#   'numBikesAvailable': 10,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 7}],
#   'num_docks_available': 38,
#   'numDocksAvailable': 38,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052128},
#  {'stationCode': '9038',
#   'station_id': 129025451,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 3}],
#   'num_docks_available': 21,
#   'numDocksAvailable': 21,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052191},
#  {'stationCode': '8009',
#   'station_id': 128920403,
#   'num_bikes_available': 23,
#   'numBikesAvailable': 23,
#   'num_bikes_available_types': [{'mechanical': 15}, {'ebike': 8}],
#   'num_docks_available': 0,
#   'numDocksAvailable': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052052},
#  {'stationCode': '1001',
#   'station_id': 323616530,
#   'num_bikes_available': 16,
#   'numBikesAvailable': 16,
#   'num_bikes_available_types': [{'mechanical': 12}, {'ebike': 4}],
#   'num_docks_available': 1,
#   'numDocksAvailable': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051991},
#  {'stationCode': '31103',
#   'station_id': 1062192012,
#   'num_bikes_available': 13,
#   'numBikesAvailable': 13,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 12}],
#   'num_docks_available': 22,
#   'numDocksAvailable': 22,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052135},
#  {'stationCode': '17008',
#   'station_id': 521393180,
#   'num_bikes_available': 15,
#   'numBikesAvailable': 15,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 11}],
#   'num_docks_available': 6,
#   'numDocksAvailable': 6,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052132},
#  {'stationCode': '15112',
#   'station_id': 576188379,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 0}],
#   'num_docks_available': 22,
#   'numDocksAvailable': 22,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052195},
#  {'stationCode': '7025',
#   'station_id': 128915891,
#   'num_bikes_available': 13,
#   'numBikesAvailable': 13,
#   'num_bikes_available_types': [{'mechanical': 12}, {'ebike': 1}],
#   'num_docks_available': 19,
#   'numDocksAvailable': 19,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052009},
#  {'stationCode': '6001',
#   'station_id': 6296,
#   'num_bikes_available': 16,
#   'numBikesAvailable': 16,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 12}],
#   'num_docks_available': 1,
#   'numDocksAvailable': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052190},
#  {'stationCode': '19105',
#   'station_id': 208795867,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 4}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051983},
#  {'stationCode': '31706',
#   'station_id': 82567101,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 2}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052146},
#  {'stationCode': '22409',
#   'station_id': 457813746,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 1}],
#   'num_docks_available': 14,
#   'numDocksAvailable': 14,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052139},
#  {'stationCode': '5020',
#   'station_id': 128882438,
#   'num_bikes_available': 30,
#   'numBikesAvailable': 30,
#   'num_bikes_available_types': [{'mechanical': 25}, {'ebike': 5}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052181},
#  {'stationCode': '19015',
#   'station_id': 50191171,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 2}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052018},
#  {'stationCode': '9022',
#   'station_id': 129014600,
#   'num_bikes_available': 19,
#   'numBikesAvailable': 19,
#   'num_bikes_available_types': [{'mechanical': 15}, {'ebike': 4}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052198},
#  {'stationCode': '26003',
#   'station_id': 3906153622,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 1}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052197},
#  {'stationCode': '17004',
#   'station_id': 129087587,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 3}],
#   'num_docks_available': 36,
#   'numDocksAvailable': 36,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052120},
#  {'stationCode': '19003',
#   'station_id': 213693511,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 0}],
#   'num_docks_available': 21,
#   'numDocksAvailable': 21,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052087},
#  {'stationCode': '8036',
#   'station_id': 82379648,
#   'num_bikes_available': 10,
#   'numBikesAvailable': 10,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 10}],
#   'num_docks_available': 22,
#   'numDocksAvailable': 22,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052201},
#  {'stationCode': '12151',
#   'station_id': 66491397,
#   'num_bikes_available': 53,
#   'numBikesAvailable': 53,
#   'num_bikes_available_types': [{'mechanical': 41}, {'ebike': 12}],
#   'num_docks_available': 5,
#   'numDocksAvailable': 5,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052201},
#  {'stationCode': '18107',
#   'station_id': 230877798,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 2}],
#   'num_docks_available': 30,
#   'numDocksAvailable': 30,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051607},
#  {'stationCode': '92007',
#   'station_id': 2515995748,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 7}],
#   'num_docks_available': 14,
#   'numDocksAvailable': 14,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051778},
#  {'stationCode': '16026',
#   'station_id': 27363162,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 2}],
#   'num_docks_available': 19,
#   'numDocksAvailable': 19,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052079},
#  {'stationCode': '9028',
#   'station_id': 129021753,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 6}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052036},
#  {'stationCode': '10107',
#   'station_id': 210740080,
#   'num_bikes_available': 12,
#   'numBikesAvailable': 12,
#   'num_bikes_available_types': [{'mechanical': 9}, {'ebike': 3}],
#   'num_docks_available': 37,
#   'numDocksAvailable': 37,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051978},
#  {'stationCode': '26002',
#   'station_id': 3906094706,
#   'num_bikes_available': 39,
#   'numBikesAvailable': 39,
#   'num_bikes_available_types': [{'mechanical': 21}, {'ebike': 18}],
#   'num_docks_available': 1,
#   'numDocksAvailable': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052169},
#  {'stationCode': '17043',
#   'station_id': 80216231,
#   'num_bikes_available': 14,
#   'numBikesAvailable': 14,
#   'num_bikes_available_types': [{'mechanical': 13}, {'ebike': 1}],
#   'num_docks_available': 25,
#   'numDocksAvailable': 25,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052156},
#  {'stationCode': '19026',
#   'station_id': 336511521,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 15,
#   'numDocksAvailable': 15,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051890},
#  {'stationCode': '16039',
#   'station_id': 82562556,
#   'num_bikes_available': 10,
#   'numBikesAvailable': 10,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 3}],
#   'num_docks_available': 39,
#   'numDocksAvailable': 39,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051842},
#  {'stationCode': '11023',
#   'station_id': 129048000,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 4}],
#   'num_docks_available': 40,
#   'numDocksAvailable': 40,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052172},
#  {'stationCode': '45003',
#   'station_id': 1062250686,
#   'num_bikes_available': 23,
#   'numBikesAvailable': 23,
#   'num_bikes_available_types': [{'mechanical': 9}, {'ebike': 14}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052194},
#  {'stationCode': '11002',
#   'station_id': 129043651,
#   'num_bikes_available': 14,
#   'numBikesAvailable': 14,
#   'num_bikes_available_types': [{'mechanical': 12}, {'ebike': 2}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052204},
#  {'stationCode': '12111',
#   'station_id': 27363489,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 4}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052104},
#  {'stationCode': '8034',
#   'station_id': 39296638,
#   'num_bikes_available': 16,
#   'numBikesAvailable': 16,
#   'num_bikes_available_types': [{'mechanical': 12}, {'ebike': 4}],
#   'num_docks_available': 17,
#   'numDocksAvailable': 17,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052080},
#  {'stationCode': '11047',
#   'station_id': 813544903,
#   'num_bikes_available': 29,
#   'numBikesAvailable': 29,
#   'num_bikes_available_types': [{'mechanical': 20}, {'ebike': 9}],
#   'num_docks_available': 0,
#   'numDocksAvailable': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052198},
#  {'stationCode': '19043',
#   'station_id': 205938683,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 4}],
#   'num_docks_available': 48,
#   'numDocksAvailable': 48,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052048},
#  {'stationCode': '5032',
#   'station_id': 210399835,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 5}],
#   'num_docks_available': 29,
#   'numDocksAvailable': 29,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052201},
#  {'stationCode': '20042',
#   'station_id': 102324803,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 3}],
#   'num_docks_available': 37,
#   'numDocksAvailable': 37,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052189},
#  {'stationCode': '15067',
#   'station_id': 101763163,
#   'num_bikes_available': 11,
#   'numBikesAvailable': 11,
#   'num_bikes_available_types': [{'mechanical': 6}, {'ebike': 5}],
#   'num_docks_available': 0,
#   'numDocksAvailable': 0,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051912},
#  {'stationCode': '43401',
#   'station_id': 653133605,
#   'num_bikes_available': 18,
#   'numBikesAvailable': 18,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 11}],
#   'num_docks_available': 27,
#   'numDocksAvailable': 27,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052175},
#  {'stationCode': '17030',
#   'station_id': 126050442,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 3}],
#   'num_docks_available': 14,
#   'numDocksAvailable': 14,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051624},
#  {'stationCode': '6006',
#   'station_id': 27414578,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 1}],
#   'num_docks_available': 16,
#   'numDocksAvailable': 16,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051960},
#  {'stationCode': '11027',
#   'station_id': 54000569,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 6}],
#   'num_docks_available': 30,
#   'numDocksAvailable': 30,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051895},
#  {'stationCode': '12128',
#   'station_id': 508042092,
#   'num_bikes_available': 11,
#   'numBikesAvailable': 11,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 4}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051873},
#  {'stationCode': '8010',
#   'station_id': 42603855,
#   'num_bikes_available': 9,
#   'numBikesAvailable': 9,
#   'num_bikes_available_types': [{'mechanical': 6}, {'ebike': 3}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052192},
#  {'stationCode': '31022',
#   'station_id': 818302209,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 51,
#   'numDocksAvailable': 51,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052156},
#  {'stationCode': '19101',
#   'station_id': 13718041,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 22,
#   'numDocksAvailable': 22,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052154},
#  {'stationCode': '14003',
#   'station_id': 265464297,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 3}],
#   'num_docks_available': 45,
#   'numDocksAvailable': 45,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052195},
#  {'stationCode': '46002',
#   'station_id': 1057392676,
#   'num_bikes_available': 24,
#   'numBikesAvailable': 24,
#   'num_bikes_available_types': [{'mechanical': 14}, {'ebike': 10}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052118},
#  {'stationCode': '18003',
#   'station_id': 102309973,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 4}],
#   'num_docks_available': 37,
#   'numDocksAvailable': 37,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052092},
#  {'stationCode': '11113',
#   'station_id': 532054446,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 6}, {'ebike': 1}],
#   'num_docks_available': 49,
#   'numDocksAvailable': 49,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052196},
#  {'stationCode': '10016',
#   'station_id': 129034587,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 3}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051733},
#  {'stationCode': '31009',
#   'station_id': 261987383,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052025},
#  {'stationCode': '41302',
#   'station_id': 314829539,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 5}],
#   'num_docks_available': 42,
#   'numDocksAvailable': 42,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052077},
#  {'stationCode': '14020',
#   'station_id': 1057324291,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 2}],
#   'num_docks_available': 54,
#   'numDocksAvailable': 54,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052125},
#  {'stationCode': '5018',
#   'station_id': 37815993,
#   'num_bikes_available': 24,
#   'numBikesAvailable': 24,
#   'num_bikes_available_types': [{'mechanical': 20}, {'ebike': 4}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052176},
#  {'stationCode': '33017',
#   'station_id': 583539396,
#   'num_bikes_available': 10,
#   'numBikesAvailable': 10,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 8}],
#   'num_docks_available': 16,
#   'numDocksAvailable': 16,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052123},
#  {'stationCode': '15042',
#   'station_id': 101753100,
#   'num_bikes_available': 10,
#   'numBikesAvailable': 10,
#   'num_bikes_available_types': [{'mechanical': 8}, {'ebike': 2}],
#   'num_docks_available': 5,
#   'numDocksAvailable': 5,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052182},
#  {'stationCode': '20112',
#   'station_id': 27415466,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 3}],
#   'num_docks_available': 19,
#   'numDocksAvailable': 19,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052118},
#  {'stationCode': '4010',
#   'station_id': 476155906,
#   'num_bikes_available': 20,
#   'numBikesAvailable': 20,
#   'num_bikes_available_types': [{'mechanical': 16}, {'ebike': 4}],
#   'num_docks_available': 4,
#   'numDocksAvailable': 4,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052189},
#  {'stationCode': '18011',
#   'station_id': 81081358,
#   'num_bikes_available': 11,
#   'numBikesAvailable': 11,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 7}],
#   'num_docks_available': 25,
#   'numDocksAvailable': 25,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052110},
#  {'stationCode': '43008',
#   'station_id': 66491385,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 2}],
#   'num_docks_available': 19,
#   'numDocksAvailable': 19,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
# ...
#   'numBikesAvailable': 10,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 9}],
#   'num_docks_available': 26,
#   'numDocksAvailable': 26,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052178},
#  {'stationCode': '33012',
#   'station_id': 27414713,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 2}],
#   'num_docks_available': 25,
#   'numDocksAvailable': 25,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052185},
#  {'stationCode': '10019',
#   'station_id': 54000564,
#   'num_bikes_available': 8,
#   'numBikesAvailable': 8,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 6}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051999},
#  {'stationCode': '11033',
#   'station_id': 27363337,
#   'num_bikes_available': 29,
#   'numBikesAvailable': 29,
#   'num_bikes_available_types': [{'mechanical': 21}, {'ebike': 8}],
#   'num_docks_available': 4,
#   'numDocksAvailable': 4,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052202},
#  {'stationCode': '41203',
#   'station_id': 100967498,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 2}],
#   'num_docks_available': 45,
#   'numDocksAvailable': 45,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052053},
#  {'stationCode': '10033',
#   'station_id': 6298,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052125},
#  {'stationCode': '13035',
#   'station_id': 452341449,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 0,
#   'numDocksAvailable': 0,
#   'is_installed': 1,
#   'is_returning': 0,
#   'is_renting': 0,
#   'last_reported': 1701259757},
#  {'stationCode': '18039',
#   'station_id': 43247025,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 3}],
#   'num_docks_available': 15,
#   'numDocksAvailable': 15,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052204},
#  {'stationCode': '16005',
#   'station_id': 70903158,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 1}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052113},
#  {'stationCode': '17009',
#   'station_id': 37879071,
#   'num_bikes_available': 9,
#   'numBikesAvailable': 9,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 5}],
#   'num_docks_available': 23,
#   'numDocksAvailable': 23,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052160},
#  {'stationCode': '5007',
#   'station_id': 82332239,
#   'num_bikes_available': 16,
#   'numBikesAvailable': 16,
#   'num_bikes_available_types': [{'mechanical': 8}, {'ebike': 8}],
#   'num_docks_available': 17,
#   'numDocksAvailable': 17,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052087},
#  {'stationCode': '20022',
#   'station_id': 54000619,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 32,
#   'numDocksAvailable': 32,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051780},
#  {'stationCode': '4006',
#   'station_id': 265201872,
#   'num_bikes_available': 48,
#   'numBikesAvailable': 48,
#   'num_bikes_available_types': [{'mechanical': 44}, {'ebike': 4}],
#   'num_docks_available': 4,
#   'numDocksAvailable': 4,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052178},
#  {'stationCode': '12036',
#   'station_id': 101008598,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 4}],
#   'num_docks_available': 36,
#   'numDocksAvailable': 36,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052204},
#  {'stationCode': '14026',
#   'station_id': 75525462,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 1}],
#   'num_docks_available': 42,
#   'numDocksAvailable': 42,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052147},
#  {'stationCode': '16105',
#   'station_id': 15462861,
#   'num_bikes_available': 1,
#   'numBikesAvailable': 1,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 1}],
#   'num_docks_available': 29,
#   'numDocksAvailable': 29,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051934},
#  {'stationCode': '10008',
#   'station_id': 95845524,
#   'num_bikes_available': 16,
#   'numBikesAvailable': 16,
#   'num_bikes_available_types': [{'mechanical': 14}, {'ebike': 2}],
#   'num_docks_available': 1,
#   'numDocksAvailable': 1,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052127},
#  {'stationCode': '16012',
#   'station_id': 38407,
#   'num_bikes_available': 12,
#   'numBikesAvailable': 12,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 9}],
#   'num_docks_available': 28,
#   'numDocksAvailable': 28,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052195},
#  {'stationCode': '16036',
#   'station_id': 82554449,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 2}],
#   'num_docks_available': 54,
#   'numDocksAvailable': 54,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052103},
#  {'stationCode': '42505',
#   'station_id': 39535340,
#   'num_bikes_available': 12,
#   'numBikesAvailable': 12,
#   'num_bikes_available_types': [{'mechanical': 7}, {'ebike': 5}],
#   'num_docks_available': 17,
#   'numDocksAvailable': 17,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051895},
#  {'stationCode': '8117',
#   'station_id': 1062797394,
#   'num_bikes_available': 19,
#   'numBikesAvailable': 19,
#   'num_bikes_available_types': [{'mechanical': 17}, {'ebike': 2}],
#   'num_docks_available': 3,
#   'numDocksAvailable': 3,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052192},
#  {'stationCode': '10032',
#   'station_id': 66491391,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 0}],
#   'num_docks_available': 29,
#   'numDocksAvailable': 29,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052171},
#  {'stationCode': '12015',
#   'station_id': 54000570,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 3}],
#   'num_docks_available': 29,
#   'numDocksAvailable': 29,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052020},
#  {'stationCode': '48004',
#   'station_id': 1062256852,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 19,
#   'numDocksAvailable': 19,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052026},
#  {'stationCode': '26004',
#   'station_id': 1057373549,
#   'num_bikes_available': 13,
#   'numBikesAvailable': 13,
#   'num_bikes_available_types': [{'mechanical': 9}, {'ebike': 4}],
#   'num_docks_available': 9,
#   'numDocksAvailable': 9,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052071},
#  {'stationCode': '18139',
#   'station_id': 653089942,
#   'num_bikes_available': 9,
#   'numBikesAvailable': 9,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 7}],
#   'num_docks_available': 12,
#   'numDocksAvailable': 12,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052194},
#  {'stationCode': '16042',
#   'station_id': 201923447,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 0}],
#   'num_docks_available': 33,
#   'numDocksAvailable': 33,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052164},
#  {'stationCode': '1006',
#   'station_id': 220504949,
#   'num_bikes_available': 16,
#   'numBikesAvailable': 16,
#   'num_bikes_available_types': [{'mechanical': 13}, {'ebike': 3}],
#   'num_docks_available': 13,
#   'numDocksAvailable': 13,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052110},
#  {'stationCode': '15001',
#   'station_id': 38060,
#   'num_bikes_available': 40,
#   'numBikesAvailable': 40,
#   'num_bikes_available_types': [{'mechanical': 11}, {'ebike': 29}],
#   'num_docks_available': 2,
#   'numDocksAvailable': 2,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052106},
#  {'stationCode': '15008',
#   'station_id': 41464928,
#   'num_bikes_available': 6,
#   'numBikesAvailable': 6,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 3}],
#   'num_docks_available': 53,
#   'numDocksAvailable': 53,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052043},
#  {'stationCode': '19110',
#   'station_id': 27296946,
#   'num_bikes_available': 11,
#   'numBikesAvailable': 11,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 10}],
#   'num_docks_available': 18,
#   'numDocksAvailable': 18,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052046},
#  {'stationCode': '11112',
#   'station_id': 15308712,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 1}],
#   'num_docks_available': 21,
#   'numDocksAvailable': 21,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052085},
#  {'stationCode': '22201',
#   'station_id': 653143563,
#   'num_bikes_available': 5,
#   'numBikesAvailable': 5,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 5}],
#   'num_docks_available': 25,
#   'numDocksAvailable': 25,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051932},
#  {'stationCode': '18202',
#   'station_id': 9931940126,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 3}, {'ebike': 4}],
#   'num_docks_available': 31,
#   'numDocksAvailable': 31,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052128},
#  {'stationCode': '3008',
#   'station_id': 443153677,
#   'num_bikes_available': 30,
#   'numBikesAvailable': 30,
#   'num_bikes_available_types': [{'mechanical': 26}, {'ebike': 4}],
#   'num_docks_available': 5,
#   'numDocksAvailable': 5,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052130},
#  {'stationCode': '6010',
#   'station_id': 7295,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 3}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051894},
#  {'stationCode': '5015',
#   'station_id': 66505510,
#   'num_bikes_available': 35,
#   'numBikesAvailable': 35,
#   'num_bikes_available_types': [{'mechanical': 21}, {'ebike': 14}],
#   'num_docks_available': 27,
#   'numDocksAvailable': 27,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052188},
#  {'stationCode': '1020',
#   'station_id': 128841079,
#   'num_bikes_available': 18,
#   'numBikesAvailable': 18,
#   'num_bikes_available_types': [{'mechanical': 5}, {'ebike': 13}],
#   'num_docks_available': 14,
#   'numDocksAvailable': 14,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052200},
#  {'stationCode': '45002',
#   'station_id': 1062245074,
#   'num_bikes_available': 19,
#   'numBikesAvailable': 19,
#   'num_bikes_available_types': [{'mechanical': 16}, {'ebike': 3}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702051886},
#  {'stationCode': '15128',
#   'station_id': 1057758764,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 2}],
#   'num_docks_available': 32,
#   'numDocksAvailable': 32,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052121},
#  {'stationCode': '44014',
#   'station_id': 653144717,
#   'num_bikes_available': 14,
#   'numBikesAvailable': 14,
#   'num_bikes_available_types': [{'mechanical': 2}, {'ebike': 12}],
#   'num_docks_available': 11,
#   'numDocksAvailable': 11,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052104},
#  {'stationCode': '12037',
#   'station_id': 42275164,
#   'num_bikes_available': 2,
#   'numBikesAvailable': 2,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 1}],
#   'num_docks_available': 34,
#   'numDocksAvailable': 34,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052119},
#  {'stationCode': '1007',
#   'station_id': 75345531,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 6}, {'ebike': 1}],
#   'num_docks_available': 7,
#   'numDocksAvailable': 7,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052184},
#  {'stationCode': '16037',
#   'station_id': 85031184,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 5}, {'ebike': 2}],
#   'num_docks_available': 45,
#   'numDocksAvailable': 45,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052018},
#  {'stationCode': '47003',
#   'station_id': 97824043,
#   'num_bikes_available': 12,
#   'numBikesAvailable': 12,
#   'num_bikes_available_types': [{'mechanical': 8}, {'ebike': 4}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052189},
#  {'stationCode': '18004',
#   'station_id': 66491379,
#   'num_bikes_available': 3,
#   'numBikesAvailable': 3,
#   'num_bikes_available_types': [{'mechanical': 1}, {'ebike': 2}],
#   'num_docks_available': 7,
#   'numDocksAvailable': 7,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052155},
#  {'stationCode': '20034',
#   'station_id': 39169029,
#   'num_bikes_available': 4,
#   'numBikesAvailable': 4,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 4}],
#   'num_docks_available': 20,
#   'numDocksAvailable': 20,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052155},
#  {'stationCode': '16013',
#   'station_id': 35600927,
#   'num_bikes_available': 0,
#   'numBikesAvailable': 0,
#   'num_bikes_available_types': [{'mechanical': 0}, {'ebike': 0}],
#   'num_docks_available': 34,
#   'numDocksAvailable': 34,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052104},
#  {'stationCode': '7012',
#   'station_id': 100868590,
#   'num_bikes_available': 17,
#   'numBikesAvailable': 17,
#   'num_bikes_available_types': [{'mechanical': 12}, {'ebike': 5}],
#   'num_docks_available': 8,
#   'numDocksAvailable': 8,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052194},
#  {'stationCode': '20001',
#   'station_id': 30730,
#   'num_bikes_available': 7,
#   'numBikesAvailable': 7,
#   'num_bikes_available_types': [{'mechanical': 4}, {'ebike': 3}],
#   'num_docks_available': 27,
#   'numDocksAvailable': 27,
#   'is_installed': 1,
#   'is_returning': 1,
#   'is_renting': 1,
#   'last_reported': 1702052197},
#  ...]
